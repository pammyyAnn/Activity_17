# %% [markdown]
# <a href="https://colab.research.google.com/github/pammyyAnn/Activity_17/blob/main/Activity17Pam.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd

# %%
filename = '/content/drive/MyDrive/FINAL_ACT1_PAM/pll-team-stats.csv'
df = pd.read_csv(filename)
df.head()
# Out:
#    season        team  wins  losses  scores_for  scores_against  \
# 0    2019       Chaos     7       3         130             128
# 1    2019  Whipsnakes     6       4         125             116
# 2    2019       Atlas     5       5         125             132
# 3    2019    Redwoods     5       5         116             117
# 4    2019     Archers     5       5         112             106
#
#    score_differential  one_point_goals  two_point_goals  assists  ...  \
# 0                   2              106               12       67  ...
# 1                   9              101               12       71  ...
# 2                  -7              109                8       73  ...
# 3                  -1              112                2       61  ...
# 4                   6              100                6       67  ...
#
#    save_percentage  penalties  penalty_minutes  power_play_pecentage  \
# 0            0.555         33             18.0                 0.478
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 29 entries, 0 to 28
# Data columns (total 33 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   season                   29 non-null     int64
#  1   team                     29 non-null     object
#  2   wins                     29 non-null     int64
#  3   losses                   29 non-null     int64
#  4   scores_for               29 non-null     int64
#  5   scores_against           29 non-null     int64
#  6   score_differential       29 non-null     int64
#  7   one_point_goals          29 non-null     int64
#  8   two_point_goals          29 non-null     int64
#  9   assists                  29 non-null     int64
#  10  shots                    29 non-null     int64
#  11  shot_percentage          29 non-null     float64
#  12  x2_point_shots           29 non-null     int64
#  13  x2_point_shot_pecentage  29 non-null     float64
# ...

# %%
df.describe().round(2)
# Out:
#         season   wins  losses  scores_for  scores_against  score_differential  \
# count    29.00  29.00   29.00       29.00           29.00               29.00
# mean   2020.62   4.14    4.14      102.83          102.86               -0.03
# std       1.12   2.17    2.17       25.93           26.34               14.65
# min    2019.00   0.00    0.00       46.00           51.00              -29.00
# 25%    2020.00   2.00    3.00       92.00           95.00              -10.00
# 50%    2021.00   5.00    4.00      111.00          108.00               -1.00
# 75%    2022.00   6.00    5.00      120.00          120.00                9.00
# max    2022.00   9.00    9.00      130.00          140.00               31.00
#
#        one_point_goals  two_point_goals  assists   shots  ...  faceoffs_lost  \
# count            29.00            29.00    29.00   29.00  ...          29.00
# mean             90.21             6.31    54.62  345.52  ...         112.52
# ...

# %%
df['wins'].mean()
# Out:
# 4.137931034482759

# %%
df.groupby('team')['wins'].mean()
# Out:
# team
# Archers       4.75
# Atlas         4.50
# Cannons       2.00
# Chaos         3.25
# Chrome        3.50
# Redwoods      4.00
# Waterdogs     4.00
# Whipsnakes    6.00
# Name: wins, dtype: float64

# %%
df.groupby(['team', 'playoff_notes'])['wins'].mean()
# Out:
# team        playoff_notes
# Archers     Lost Quarterfinals    5.0
#             Lost Semifinals       4.5
#             Missed Playoffs       5.0
# Atlas       Lost Quarterfinals    4.0
#             Lost Semifinals       6.0
# Cannons     Lost Quarterfinals    3.0
#             Missed Playoffs       1.0
# Chaos       Lost Final            1.0
#             Lost Semifinals       7.0
#             Won Final             4.0
# Chrome      Lost Quarterfinals    5.0
#             Missed Playoffs       2.0
# Redwoods    Lost Final            5.0
#             Lost Quarterfinals    4.5
#             Lost Semifinals       2.0
# Waterdogs   Lost Quarterfinals    1.0
#             Lost Semifinals       6.0
#             Won Final             5.0
# Whipsnakes  Lost Final            5.0
#             Lost Semifinals       9.0
#             Won Final             5.0
# Name: wins, dtype: float64
